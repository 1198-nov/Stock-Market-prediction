# %% [markdown]
# importing all the required libreries for the code

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn.objects as so
import seaborn as sns
import plotly.graph_objs as go
from dash import Dash, dcc, html, Input, Output
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import linear_model
from sklearn import metrics
from sklearn.svm import SVC
from xgboost import XGBClassifier
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tsa.stattools import adfuller
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import math

# %%
tesla_data = pd.read_csv("./Data/tesla_data.csv") #Importing the tesla data

# %%
tesla_data # reading the data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume
# 0     18766300
# 1     17187100
# 2      8218800
# 3      5139800
# 4      6866900
# ...        ...
# 2411  11788500
# 2412  17801500
# 2413  29005700
# 2414  15719300
# 2415  47065000
#
# [2416 rows x 7 columns]

# %%
tesla_data.shape # printing the number of rows and columns from the data
# Out:
# (2416, 7)

# %%
tesla_data.head() # Printing the first five rows of the data
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
tesla_data.tail() # printing the last five rows of the data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume
# 2411  11788500
# 2412  17801500
# 2413  29005700
# 2414  15719300
# 2415  47065000

# %%
tesla_data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2416.000000  2416.000000  2416.000000  2416.000000  2416.000000
# mean    186.271147   189.578224   182.916639   186.403651   186.403651
# std     118.740163   120.892329   116.857591   119.136020   119.136020
# min      16.139999    16.629999    14.980000    15.800000    15.800000
# 25%      34.342498    34.897501    33.587501    34.400002    34.400002
# 50%     213.035004   216.745002   208.870002   212.960007   212.960007
# 75%     266.450012   270.927513   262.102501   266.774994   266.774994
# max     673.690002   786.140015   673.520020   780.000000   780.000000
#
#              Volume
# count  2.416000e+03
# mean   5.572722e+06
# std    4.987809e+06
# min    1.185000e+05
# 25%    1.899275e+06
# 50%    4.578400e+06
# 75%    7.361150e+06
# max    4.706500e+07

# %%
tesla_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2416 entries, 0 to 2415
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2416 non-null   object
#  1   Open       2416 non-null   float64
#  2   High       2416 non-null   float64
#  3   Low        2416 non-null   float64
#  4   Close      2416 non-null   float64
#  5   Adj Close  2416 non-null   float64
#  6   Volume     2416 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 132.3+ KB

# %%
tesla_data.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
tesla_data['Date'] = pd.to_datetime(tesla_data['Date']) # converting the datatype of 'Date' column  to datetime

# %%
tesla_data.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
tesla_data['Month'] = tesla_data['Date'].dt.to_period('M') # converting the date into period of month

# %%
month_mean = tesla_data.groupby('Month',as_index = False).mean()
month_mean.head(3)
# Out:
#      Month                          Date       Open   High        Low  \
# 0  2010-06 2010-06-29 12:00:00.000000000  22.395001  27.71  20.420000
# 1  2010-07 2010-07-16 13:42:51.428571392  20.073334  20.64  18.816190
# 2  2010-08 2010-08-15 22:54:32.727272704  19.545455  19.91  19.080455
#
#        Close  Adj Close        Volume
# 0  23.860000  23.860000  1.797670e+07
# 1  19.558095  19.558095  3.075038e+06
# 2  19.510909  19.510909  6.835545e+05

# %%
month_mean['Month'] = month_mean['Month'].dt.to_timestamp()

# %%
month_mean.columns
# Out:
# Index(['Month', 'Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
plt.figure(figsize=(8, 6))
plt.plot(month_mean['Month'], month_mean['Open'], label='Open',marker = '*')
plt.plot(month_mean['Month'], month_mean['High'], label='High',marker = '.')
plt.plot(month_mean['Month'], month_mean['Low'], label='Low',marker = '^')
plt.plot(month_mean['Month'], month_mean['Adj Close'], label='Adj Close',marker = '<')
plt.plot(month_mean['Month'], month_mean['Close'], label='Close',marker = '>')
plt.title('Monthly Average of Stock Prices')
plt.xlabel('Month')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Monthly averages of the all the the columns ['Month', 'Date', 'Open', 'High', 'Low', 'Close', 'Adj Close']. As we can observe that all the values are closely same.

# %%
plt.subplots(figsize=(20,10))
feature = ['Open', 'Close', 'Low', 'High', 'Volume']
for i, col in enumerate(feature):
    plt.subplot(2, 3, i+1)
    sns.histplot(tesla_data[col],kde = True)
    plt.title(f"Distribution of {col}")
    
plt.tight_layout()
plt.show()

# %% [markdown]
# #####
# The price distribution (open, close, low, high): Are the prices clustered around a specific range or vary widely?
# volume distribution: Is trading volume mostly low with occasional spikes, or is it relatively uniform?

# %%
plt.subplots(figsize=(20,10))
for i, col in enumerate(feature):
    plt.subplot(2, 3, i+1)
    sns.boxplot(tesla_data[col])
    plt.title(f"Distribution of {col}") 
plt.tight_layout()
plt.show()

# %% [markdown]
# ####
# The boxplot for Tesla's stock prices(open, close, high, low) and (volume) reveals the data's spread, central tendency, and potential outliers. A wide interquartile range indicates high volatility in prices, while outliers suggest unusual trading days that may correspond to significant events
# Preprocessing steps like handling outliers or normalizing features can improve model accuracy and performance for prediction.

# %%
plt.figure(figsize=(7, 5))
plt.bar(month_mean['Month'], month_mean['Volume'], alpha = 0.6, label=' Volume of Stocks', color = 'blue')
plt.plot(month_mean['Month'], month_mean['Volume'], label = 'Volume of Stocks', marker = '.', color = 'red')
plt.title('Monthly Average Stock Volume')
plt.xlabel('Month')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %%
tesla_data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Month'], dtype='object')

# %%
app = Dash(__name__)

app.layout = html.Div([
    html.H1(children = ["Stock market Dashboard"]),
    dcc.DatePickerRange(
        id = 'date_range',
        start_date = '2010-06-29',
        end_date = '2020-02-03'
    ),
    dcc.RadioItems(
        id = 'data_res',
        options = {"1_day":"Daily"},
        value = "1_day",
        inline = True,
    ),
    dcc.Dropdown(id = 'Value Type',
                 options=[
                        {'label': ' Opening price in a day', 'value': 'Open'},
                        {'label': 'Highest price in a day', 'value': 'High'},
                        {'label': 'Lowest price in a day', 'value': 'Low'},
                        {'label': 'Close price in a day ','value':'Close'},
                        {'label': 'Adjacent Close price in a day ','value':'Adj Close'},
                        {'label': 'Volume of stock','value':'Volume'},
                        ],
                    value='Close', 
                    style={'width': '50%'}
                ),
    dcc.Graph(id = "Trend Graph")
])
@app.callback(
    Output(component_id = "Trend Graph",component_property = 'figure'),
    Input(component_id = "date_range",component_property = 'start_date'),
    Input(component_id = "date_range",component_property = 'end_date'),
    Input(component_id = "Value Type",component_property = 'value'),


)
def update_graph(start_date,end_date,Value_type):
    filtered_data = tesla_data[(tesla_data['Date'] >= start_date) & (tesla_data['Date']<= end_date)]

    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=filtered_data['Date'],
        y=filtered_data[Value_type],
        mode='lines',
        name=Value_type
    ))
    fig.update_layout(
        title=f"{Value_type} Over Time",
        xaxis_title="Date",
        yaxis_title=Value_type,
        template="plotly_dark"
    )
    
    return fig

if __name__ == '__main__':
    app.run(debug = True,port = 8060)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8060/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# This is an interactive dashboard which gives the value of the data selected from the dates. This varies for the value selected from the dropdown. which makes the more interactive. We can see the dates and the price of the data on the particular day.

# %% [markdown]
# ## Feature Engineering

# %%
tesla_data['Year'] = tesla_data['Date'].dt.to_period('Y')

# %%
tesla_data['Month'] = pd.DatetimeIndex(tesla_data['Date']).month
tesla_data['Year'] = pd.DatetimeIndex(tesla_data['Date']).year
tesla_data['Day'] = pd.DatetimeIndex(tesla_data['Date']).day
tesla_data.head(3)
# Out:
#         Date       Open   High        Low      Close  Adj Close    Volume  \
# 0 2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1 2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2 2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
#
#    Month  Year  Day
# 0      6  2010   29
# 1      6  2010   30
# 2      7  2010    1

# %%
tesla_data['IS_QuarterEnd'] = np.where(tesla_data['Month']%3 == 0,1,0)
tesla_data.head(2)
# Out:
#         Date       Open   High        Low      Close  Adj Close    Volume  \
# 0 2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1 2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
#
#    Month  Year  Day  IS_QuarterEnd
# 0      6  2010   29              1
# 1      6  2010   30              1

# %%
tesla_group = tesla_data.groupby('Year').mean()
plt.subplots(figsize=(20,10))
for i, col in enumerate(['Open', 'High', 'Low', 'Close']):
    plt.subplot(2,2,i+1)
    tesla_group[col].plot.bar()
    plt.title(f'Yearly Average of {col} Prices')

plt.tight_layout()
plt.show()

# %% [markdown]
# ####
# Yearly trends help in analyzing the annual performance of Tesla's stock prices, it provides historical context for forecasting future stock price behavior.
# Summarize data: Reduces daily fluctuations into yearly trends, making patterns easier to interpret.

# %%
tesla_data.groupby('IS_QuarterEnd').mean()

tesla_data['Open-Close'] = tesla_data['Open'] - tesla_data['Close']
tesla_data['Low-High'] = tesla_data['Low'] - tesla_data['High']
tesla_data['Goal'] = np.where(tesla_data['Close'].shift(-1) > tesla_data['Close'], 1, 0)

# %%
plt.pie(tesla_data['Goal'].value_counts().values,
        labels = [0,1], autopct = '%1.1f%%')
plt.show()

# %% [markdown]
# One is given to the diffrence of ["Open-Close"] is positive. \
# Zero is give to the difference of ["Open-Close"] is negative.
# The pie chart represents the same data.

# %%
plt.figure(figsize = (10,10))
sns.heatmap(tesla_data.corr() > 0.9, annot = True, cbar = False)
plt.show()

# %% [markdown]
# ####
# This pie chart shows the balance between days when the stock price increased(Goal = 1) and decreased when (Goal = 0), highlighting potential class imbalance for model training.
# The heatmap reveals high correlations among the original OHLC features but confirms that the newly added features (open-close, Low-High) are not highly correlated with each other.
# Overall, the dataset is well-prepared for predictive modeling, with features that enhance interpretability and model performance.

# %% [markdown]
# ### Data Splitting and Normalization

# %%
x = tesla_data[['Open-Close','Low-High', 'IS_QuarterEnd']]
y = tesla_data['Goal']

scaler = StandardScaler()
x = scaler.fit_transform(x)

X_train , X_test, y_train, y_test =  train_test_split( x,y, test_size =0.1, 
                                                      random_state = 1000)
print(X_train.shape, X_test.shape)
# Out:
# (2174, 3) (242, 3)

# %% [markdown]
# ### Model Development

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)
y_probability = clf.predict_proba(X_test)
pd.DataFrame({'y_pred':y_pred, 'y_true':y_test, 'y_probability':y_probability[:,1]})
# Out:
#       y_pred  y_true  y_probability
# 1826       1       1       0.527024
# 565        1       0       0.524265
# 853        1       0       0.507498
# 1252       1       0       0.526387
# 888        0       0       0.499169
# ...      ...     ...            ...
# 854        1       1       0.533263
# 2163       0       1       0.489351
# 526        1       1       0.509166
# 450        1       1       0.504932
# 2111       1       1       0.501328
#
# [242 rows x 3 columns]

# %%
cm = metrics.confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 29,  90],
#        [ 13, 110]], dtype=int64)

# %%
plt.figure(figsize=(8,5))
sns.heatmap(cm, annot = True, fmt = 'd', cmap = 'Blues',
            xticklabels = ['Predicted 0', 'Predicted 1'],
            yticklabels = ['Actual 0', 'Actual 1'])

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# ####
# The above heatmap shows the actual and predicted values for binary classification. It will display true negative, true positive, false positive and false negative values clearly.

# %%
model = [LogisticRegression(),
         SVC(kernel = 'poly', probability = True), XGBClassifier()]

for i in range(3):
    model[i].fit(X_train, y_train)
    train_auc = metrics.roc_auc_score(y_train, model[i].predict_proba(X_train)[:,1])
    test_auc = metrics.roc_auc_score(y_test, model[i].predict_proba(X_test)[:,1])

print(f'{model[i]}:')
print(f'Training AUC-ROC Score: {train_auc:.4f}')
print(f'Testing AUC-ROC Score: {test_auc:.4f}')
print('-'*40)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...):
# Training AUC-ROC Score: 0.9423
# Testing AUC-ROC Score: 0.5237
# ----------------------------------------

# %% [markdown]
# ####
# The XGBClassifier performs the best, but the large gap between training and testing accuracy suggests overfitting. This means its too closely fitted to the training data and may not generalize well to the new data.

# %%
for i in range(3):
    model[i].fit(X_train, y_train)
    train_rmse = metrics.root_mean_squared_error(y_train, model[i].predict_proba(X_train)[:,1])
    test_rmse = metrics.root_mean_squared_error(y_test, model[i].predict_proba(X_test)[:,1])

print(f'{model[i]}:')
print(f'Training Root meansquared error: {train_rmse:.4f}')
print(f'Testing Root meansquared error: {test_rmse:.4f}')
print('-'*40)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...):
# Training Root meansquared error: 0.3601
# Testing Root meansquared error: 0.5357
# ----------------------------------------

# %%
tesla_pivot = pd.pivot_table(tesla_data, values = ['Open','Close'],
                             columns = 'Year',
                             index = 'Month')
tesla_pivot.head(3)
# Out:
#       Close                                                          \
# Year   2010       2011      2012       2013        2014        2015
# Month
# 1       NaN  25.643000  27.49000  35.188571  164.051905  203.255499
# 2       NaN  23.333684  32.76200  37.366316  206.023157  210.673159
# 3       NaN  23.708696  35.24091  37.043000  233.146667  194.718184
#
#                                                        ...       Open  \
# Year         2016        2017        2018        2019  ...       2011
# Month                                                  ...
# 1      204.562105  239.320499  338.583335  318.494284  ...  25.807500
# 2      169.670000  263.711058  335.777369  307.728421  ...  23.395263
# 3      216.147273  258.156522  315.983335  277.757140  ...  23.640870
#
#                                                                            \
# Year      2012       2013        2014        2015        2016        2017
# Month
# 1      27.7560  35.161905  162.742382  202.902501  206.961579  237.936000
# 2      32.5145  37.528421  206.239998  209.653158  169.812499  262.833159
# 3      35.1350  37.004500  235.823809  195.458183  215.000454  257.758262
#
#
# Year         2018        2019        2020
# Month
# 1      336.888096  316.690953  523.045239
# 2      336.316840  307.196843  673.690002
# 3      317.428095  278.870953         NaN
#
# [3 rows x 22 columns]

# %%
tesla_pivot.plot(subplots = True, figsize = (20,20), layout = (5,5), sharey = True)
# Out:
# array([[<Axes: xlabel='Month'>, <Axes: xlabel='Month'>,
#         <Axes: xlabel='Month'>, <Axes: xlabel='Month'>,
#         <Axes: xlabel='Month'>],
#        [<Axes: xlabel='Month'>, <Axes: xlabel='Month'>,
#         <Axes: xlabel='Month'>, <Axes: xlabel='Month'>,
#         <Axes: xlabel='Month'>],
#        [<Axes: xlabel='Month'>, <Axes: xlabel='Month'>,
#         <Axes: xlabel='Month'>, <Axes: xlabel='Month'>,
#         <Axes: xlabel='Month'>],
#        [<Axes: xlabel='Month'>, <Axes: xlabel='Month'>,
#         <Axes: xlabel='Month'>, <Axes: xlabel='Month'>,
#         <Axes: xlabel='Month'>],
#        [<Axes: xlabel='Month'>, <Axes: xlabel='Month'>,
#         <Axes: xlabel='Month'>, <Axes: xlabel='Month'>,
#         <Axes: xlabel='Month'>]], dtype=object)

# %%
tesla_data['Openlog'] = np.log(tesla_data.Open)
tesla_data['Closelog'] = np.log(tesla_data.Close) 
tesla_data.head(3)
# Out:
#         Date       Open   High        Low      Close  Adj Close    Volume  \
# 0 2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1 2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2 2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
#
#    Month  Year  Day  IS_QuarterEnd  Open-Close  Low-High  Goal   Openlog  \
# 0      6  2010   29              1   -4.889999 -7.459999     0  2.944439
# 1      6  2010   30              1    1.960001 -7.120001     0  3.249987
# 2      7  2010    1              0    3.040001 -5.650000     0  3.218876
#
#    Closelog
# 0  3.173460
# 1  3.170945
# 2  3.089223

# %%
tesla_data.Openlog.plot()
# Out:
# <Axes: >

# %%
tesla_data.Closelog.plot()
# Out:
# <Axes: >

# %%
tesla_open_pred = tesla_data.Openlog.mean()
tesla_close_pred = tesla_data.Closelog.mean()
tesla_data['Open_mean'] = np.exp(tesla_open_pred)
tesla_data['Close_mean'] = np.exp(tesla_close_pred)

# %%
tesla_data.plot( x = 'Date', y= ['Open', 'Open_mean'], kind = 'line')
# Out:
# <Axes: xlabel='Date'>

# %%
tesla_data.plot( x = 'Date', y= ['Close', 'Close_mean'], kind = 'line')
# Out:
# <Axes: xlabel='Date'>

# %%
x_open = np.arange(tesla_data.shape[0]).reshape((-1,1))
y_open = tesla_data.Open.values.reshape((-1,1))
reg_open = linear_model.LinearRegression()
pred_open = reg_open.fit(x_open, y_open).predict(x_open)

tesla_data['linear_open'] = pred_open
tesla_data.plot( x = 'Date', y= ['Open', 'Open_mean', 'linear_open'], kind = 'line')
# Out:
# <Axes: xlabel='Date'>

# %%
tesla_data.head()
# Out:
#         Date       Open   High        Low      Close  Adj Close    Volume  \
# 0 2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1 2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2 2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3 2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4 2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900
#
#    Month  Year  Day  IS_QuarterEnd  Open-Close  Low-High  Goal   Openlog  \
# 0      6  2010   29              1   -4.889999 -7.459999     0  2.944439
# 1      6  2010   30              1    1.960001 -7.120001     0  3.249987
# 2      7  2010    1              0    3.040001 -5.650000     0  3.218876
# 3      7  2010    2              0    3.799999 -4.390001     0  3.135494
# 4      7  2010    6              0    3.889999 -4.170000     0  2.995732
#
#    Closelog   Open_mean  Close_mean  linear_open
# 0  3.173460  128.474133  128.465074     3.127004
# 1  3.170945  128.474133  128.465074     3.278676
# 2  3.089223  128.474133  128.465074     3.430348
# 3  2.954910  128.474133  128.465074     3.582020
# 4  2.779440  128.474133  128.465074     3.733693

# %%
x_close = np.arange(tesla_data.shape[0]).reshape((-1,1))
y_close = tesla_data.Close.values.reshape((-1,1))
reg_close = linear_model.LinearRegression()
pred_close = reg_close.fit(x_close, y_close).predict(x_close)

tesla_data['linear_close'] = pred_close
tesla_data.plot( x = 'Date', y= ['Close', 'Close_mean', 'linear_close'], kind = 'line')
# Out:
# <Axes: xlabel='Date'>

# %%
tesla_data.Date = pd.DatetimeIndex(tesla_data.Date)
tesla_data.index = pd.PeriodIndex(tesla_data.Date, freq = 'D')
tesla_data.head(3)

tesla_data['TimeIndex'] = tesla_data.Date - tesla_data.Date.min()
tesla_data['TimeIndex'] = tesla_data['TimeIndex'] / np.timedelta64(1,'D')
tesla_data.tail(3)
# Out:
#                  Date        Open        High        Low       Close  \
# Date
# 2020-01-30 2020-01-30  632.419983  650.880005  618.00000  640.809998
# 2020-01-31 2020-01-31  640.000000  653.000000  632.52002  650.570007
# 2020-02-03 2020-02-03  673.690002  786.140015  673.52002  780.000000
#
#              Adj Close    Volume  Month  Year  Day  ...  Open-Close  \
# Date                                                ...
# 2020-01-30  640.809998  29005700      1  2020   30  ...   -8.390015
# 2020-01-31  650.570007  15719300      1  2020   31  ...  -10.570007
# 2020-02-03  780.000000  47065000      2  2020    3  ... -106.309998
#
#               Low-High  Goal   Openlog  Closelog   Open_mean  Close_mean  \
# Date
# 2020-01-30  -32.880005     1  6.449554  6.462733  128.474133  128.465074
# 2020-01-31  -20.479980     1  6.461468  6.477849  128.474133  128.465074
# 2020-02-03 -112.619995     0  6.512770  6.659294  128.474133  128.465074
#
#             linear_open  linear_close  TimeIndex
# Date
# 2020-01-30   369.111945    369.685453     3502.0
# 2020-01-31   369.263617    369.837491     3503.0
# 2020-02-03   369.415289    369.989529     3506.0
#
# [3 rows x 21 columns]

# %%
tesla_linear_model_open = smf.ols('Openlog ~ TimeIndex', data = tesla_data).fit()
tesla_linear_model_open.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Openlog   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     8182.
# Date:                Thu, 12 Dec 2024   Prob (F-statistic):               0.00
# Time:                        13:29:13   Log-Likelihood:                -1671.8
# No. Observations:                2416   AIC:                             3348.
# Df Residuals:                    2414   BIC:                             3359.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.3161      0.020    168.674      0.000       3.278       3.355
# TimeIndex      0.0009   9.72e-06     90.456      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                      573.291   Durbin-Watson:                   0.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              124.039
# Skew:                           0.236   Prob(JB):                     1.16e-27
# Kurtosis:                       1.995   Cond. No.                     4.04e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.04e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
tesla_linear_model_open.params
# Out:
# Intercept    3.316076
# TimeIndex    0.000879
# dtype: float64

# %%
tesla_linear_pred_open = tesla_linear_model_open.predict()
tesla_data['Linear_stat_model_open'] = tesla_linear_pred_open
tesla_data.tail(3)
# Out:
#                  Date        Open        High        Low       Close  \
# Date
# 2020-01-30 2020-01-30  632.419983  650.880005  618.00000  640.809998
# 2020-01-31 2020-01-31  640.000000  653.000000  632.52002  650.570007
# 2020-02-03 2020-02-03  673.690002  786.140015  673.52002  780.000000
#
#              Adj Close    Volume  Month  Year  Day  ...    Low-High  Goal  \
# Date                                                ...
# 2020-01-30  640.809998  29005700      1  2020   30  ...  -32.880005     1
# 2020-01-31  650.570007  15719300      1  2020   31  ...  -20.479980     1
# 2020-02-03  780.000000  47065000      2  2020    3  ... -112.619995     0
#
#              Openlog  Closelog   Open_mean  Close_mean  linear_open  \
# Date
# 2020-01-30  6.449554  6.462733  128.474133  128.465074   369.111945
# 2020-01-31  6.461468  6.477849  128.474133  128.465074   369.263617
# 2020-02-03  6.512770  6.659294  128.474133  128.465074   369.415289
#
#             linear_close  TimeIndex  Linear_stat_model_open
# Date
# 2020-01-30    369.685453     3502.0                6.394561
# 2020-01-31    369.837491     3503.0                6.395440
# 2020-02-03    369.989529     3506.0                6.398077
#
# [3 rows x 22 columns]

# %% [markdown]
# #### Below shows the linear model data for open column

# %%
tesla_linear_model_open.resid.plot(kind = 'bar', color = 'red',ylabel = 'Residue').get_xaxis().set_visible(False)

# %%
forecast_tesla_open =  tesla_linear_model_open.predict(exog = pd.DataFrame(dict(TimeIndex = 252),
                                                                 index = [0]))
tesla_data['Linear_Price_open'] = np.exp(tesla_linear_pred_open)
tesla_data.plot(x = 'TimeIndex', y = ['Open', 'Open_mean', 'Linear_Price_open'], kind = 'line',ylabel= 'Prices')
# Out:
# <Axes: xlabel='TimeIndex', ylabel='Prices'>

# %%
tesla_linear_model_close = smf.ols('Closelog ~ TimeIndex', data = tesla_data).fit()
tesla_linear_model_close.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Closelog   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     8196.
# Date:                Thu, 12 Dec 2024   Prob (F-statistic):               0.00
# Time:                        13:29:18   Log-Likelihood:                -1672.8
# No. Observations:                2416   AIC:                             3350.
# Df Residuals:                    2414   BIC:                             3361.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.3141      0.020    168.505      0.000       3.276       3.353
# TimeIndex      0.0009   9.72e-06     90.531      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                      573.875   Durbin-Watson:                   0.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              123.753
# Skew:                           0.234   Prob(JB):                     1.34e-27
# Kurtosis:                       1.995   Cond. No.                     4.04e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.04e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
tesla_linear_model_close.params
# Out:
# Intercept    3.314108
# TimeIndex    0.000880
# dtype: float64

# %%
tesla_linear_model_close.rsquared
# Out:
# 0.7724753529673801

# %%
tesla_linear_pred_close = tesla_linear_model_close.predict()
tesla_data['Linear_stat_model_close'] = tesla_linear_pred_open
tesla_data.tail(3)
# Out:
#                  Date        Open        High        Low       Close  \
# Date
# 2020-01-30 2020-01-30  632.419983  650.880005  618.00000  640.809998
# 2020-01-31 2020-01-31  640.000000  653.000000  632.52002  650.570007
# 2020-02-03 2020-02-03  673.690002  786.140015  673.52002  780.000000
#
#              Adj Close    Volume  Month  Year  Day  ...   Openlog  Closelog  \
# Date                                                ...
# 2020-01-30  640.809998  29005700      1  2020   30  ...  6.449554  6.462733
# 2020-01-31  650.570007  15719300      1  2020   31  ...  6.461468  6.477849
# 2020-02-03  780.000000  47065000      2  2020    3  ...  6.512770  6.659294
#
#              Open_mean  Close_mean  linear_open  linear_close  TimeIndex  \
# Date
# 2020-01-30  128.474133  128.465074   369.111945    369.685453     3502.0
# 2020-01-31  128.474133  128.465074   369.263617    369.837491     3503.0
# 2020-02-03  128.474133  128.465074   369.415289    369.989529     3506.0
#
#             Linear_stat_model_open  Linear_Price_open  Linear_stat_model_close
# Date
# 2020-01-30                6.394561         598.580590                 6.394561
# 2020-01-31                6.395440         599.107013                 6.395440
# 2020-02-03                6.398077         600.689060                 6.398077
#
# [3 rows x 24 columns]

# %% [markdown]
# #### Below shows the Linear model data for the close column

# %%
tesla_linear_model_close.resid.plot(kind = 'bar', color = 'red',ylabel='Residue').get_xaxis().set_visible(False)

# %%
forecast_tesla_close =  tesla_linear_model_close.predict(exog = pd.DataFrame(dict(TimeIndex = 252),
                                                                 index = [0]))
tesla_data['Linear_Price_close'] = np.exp(tesla_linear_pred_close)
tesla_data.plot(x = 'TimeIndex', y = ['Close', 'Close_mean', 'Linear_Price_close'], kind = 'line',ylabel = 'Prices')
# Out:
# <Axes: xlabel='TimeIndex', ylabel='Prices'>

# %% [markdown]
# ### LSTM Model For Close feature

# %%
tesla = pd.read_csv("./Data/tesla_data.csv")

Close_data = tesla[['Close']].values

scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(Close_data)

# %%
def create_dataset(dataset, time_step=1):
    Close_dataX, Close_dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]  
        Close_dataX.append(a)
        Close_dataY.append(dataset[i + time_step, 0]) 
    return np.array(Close_dataX), np.array(Close_dataY)

# %%
training_size = int(len(data_scaled) * 0.7)  
test_size = len(data_scaled) - training_size  
train_data, test_data = data_scaled[0:training_size, :], data_scaled[training_size:len(data_scaled), :]

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

model_1 = tf.keras.Sequential([
    tf.keras.layers.LSTM(50, return_sequences=True, input_shape=(100, 1)), 
    tf.keras.layers.LSTM(50, return_sequences=False),  
    tf.keras.layers.Dense(25), 
    tf.keras.layers.Dense(1) 
])
model_1.summary()
# Out:
# C:\Users\Abhi\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 25)                  │           1,275 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              26 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 31,901 (124.61 KB)
#  Trainable params: 31,901 (124.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_1.compile(optimizer='adam', loss='mean_squared_error')

model_1.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 0.0129 - val_loss: 0.0023
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.0570e-04 - val_loss: 0.0016
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.4300e-04 - val_loss: 0.0011
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.2322e-04 - val_loss: 0.0011
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.0737e-04 - val_loss: 0.0012
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss:
_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

train_rmse = math.sqrt(mean_squared_error(scaler.inverse_transform(y_train.reshape(-1, 1)), train_predict))
test_rmse = math.sqrt(mean_squared_error(scaler.inverse_transform(y_test.reshape(-1, 1)), test_predict))

print(f"Training RMSE: {train_rmse:.4f}")
print(f"Testing RMSE: {test_rmse:.4f}")
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Training RMSE: 5.7990
# Testing RMSE: 12.2564

# %%
train_plot = np.empty_like(data_scaled)
train_plot[:, :] = np.nan
train_plot[time_step:len(train_predict) + time_step, :] = train_predict

test_plot = np.empty_like(data_scaled)
test_plot[:, :] = np.nan
test_plot[len(train_predict) + (time_step * 2) + 1:len(data_scaled) - 1, :] = test_predict

# %%
plt.figure(figsize=(14, 8))
plt.plot(scaler.inverse_transform(data_scaled), label='Original Data')
plt.plot(train_plot, label='Training Predictions')
plt.plot(test_plot, label='Testing Predictions')
plt.title('Tesla Stock Price Prediction Using LSTM for Close feature')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# ### LSTM Model For Open feature

# %%
tesla = pd.read_csv("./Data/tesla_data.csv")
Open_data = tesla[['Open']].values
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(Open_data)

# %%
def create_dataset(dataset, time_step=1):
    Open_dataX, Open_dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]  
        Open_dataX.append(a)
        Open_dataY.append(dataset[i + time_step, 0]) 
    return np.array(Open_dataX), np.array(Open_dataY)

# %%
training_size = int(len(data_scaled) * 0.8)  
test_size = len(data_scaled) - training_size  
train_data, test_data = data_scaled[0:training_size, :], data_scaled[training_size:len(data_scaled), :]

# %%
time_step = 100

X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

model_2 = tf.keras.Sequential([
    tf.keras.layers.LSTM(50, return_sequences=True, input_shape=(100, 1)), 
    tf.keras.layers.LSTM(50, return_sequences=False),  
    tf.keras.layers.Dense(25), 
    tf.keras.layers.Dense(1) 
])
model_2.summary()
# Out:
# C:\Users\Abhi\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                        │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 25)                  │           1,275 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              26 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 31,901 (124.61 KB)
#  Trainable params: 31,901 (124.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_2.compile(optimizer='adam', loss='mean_squared_error')

model_2.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 0.0260 - val_loss: 0.0024
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 6.4622e-04 - val_loss: 0.0015
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.3913e-04 - val_loss: 0.0015
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.3896e-04 - val_loss: 0.0017
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.0971e-04 - val_loss: 0.0016
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.8959e-04 - val_loss: 0.0017
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.9425e-04 - val_loss: 0.0015
# Epoch 8/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.7710e-04 - val_loss: 0.0014
# Epoch 9/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.9111e-04 - val_loss: 0.0015
# Epoch 10/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.7012e-04 - val_loss: 0.0013
# Epoch 11/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.7397e-04 - val_loss: 0.0014
# Epoch 12/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.6274e-04 - val_loss: 0.0012
# Epoch 13/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.7470e-04 - val_loss: 0.0013
# Epoch 14/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.5570e-04 - val_loss: 0.0013
# Epoch 15/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.3742e-04 - val_loss: 0.0011
# Epoch 16/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.4842e-04 - val_loss: 0.0011
# Epoch 17/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.0731e-04 - val_loss: 0.0011
# Epoch 18/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.3378e-04 - val_loss: 0.0011
# Epoch 19/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.7433e-04 - val_loss: 0.0010
# Epoch 20/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.1344e-04 - val_loss: 9.9037e-04
# Epoch 21/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.1593e-04 - val_loss: 9.9432e-04
# Epoch 22/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.1816e-04 - val_loss: 0.0010
# Epoch 23/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.9931e-04 - val_loss: 9.2169e-04
# Epoch 24/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.8099e-04 - val_loss: 9.0819e-04
# Epoch 25/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 2.0656e-04 - val_loss: 8.7436e-04
# Epoch 26/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 2.2941e-04 - val_loss: 8.8784e-04
# Epoch 27/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 1.8748e-04 - val_loss: 8.8822e-04
# Epoch 28/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 1.8693e-04 - val_loss: 8.1078e-04
# Epoch 29/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 1.8246e-04 - val_loss: 8.0655e-04
# Epoch 30/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 1.8114e-04 - val_loss: 8.0577e-04
# Epoch 31/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 1.6519e-04 - val_loss: 7.4845e-04
# Epoch 32/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.8264e-04 - val_loss: 7.3971e-04
# Epoch 33/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 1.8474e-04 - val_loss: 7.2067e-04
# Epoch 34/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 1.8271e-04 - val_loss: 7.2516e-04
# Epoch 35/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.5621e-04 - val_loss: 7.4639e-04
# Epoch 36/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 1.6629e-04 - val_loss: 6.9280e-04
# Epoch 37/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 1.5865e-04 - val_loss: 6.7174e-04
# Epoch 38/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 1.5382e-04 - val_loss: 7.0342e-04
# Epoch 39/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 1.6235e-04 - val_loss: 6.6464e-04
# Epoch 40/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 1.3641e-04 - val_loss: 6.4282e-04
# Epoch 41/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 1.6018e-04 - val_loss: 6.3020e-04
# Epoch 42/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.7050e-04 - val_loss: 6.3105e-04
# Epoch 43/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.3270e-04 - val_loss: 6.6081e-04
# Epoch 44/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.5627e-04 - val_loss: 6.1039e-04
# Epoch 45/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.4431e-04 - val_loss: 5.8148e-04
# Epoch 46/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.4645e-04 - val_loss: 6.6487e-04
# Epoch 47/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 1.2847e-04 - val_loss: 6.2367e-04
# Epoch 48/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 1.2936e-04 - val_loss: 5.6464e-04
# Epoch 49/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 1.1761e-04 - val_loss: 5.2220e-04
# Epoch 50/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 1.3959e-04 - val_loss: 5.4976e-04
# Epoch 51/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.1805e-04 - val_loss: 5.8238e-04
# Epoch 52/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.1164e-04 - val_loss: 5.0495e-04
# Epoch 53/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 1.2568e-04 - val_loss: 5.0214e-04
# Epoch 54/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.2371e-04 - val_loss: 5.0104e-04
# Epoch 55/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.2274e-04 - val_loss: 5.1361e-04
# Epoch 56/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.0710e-04 - val_loss: 5.9767e-04
# Epoch 57/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.1056e-04 - val_loss: 4.6191e-04
# Epoch 58/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.1132e-04 - val_loss: 4.4694e-04
# Epoch 59/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.2131e-04 - val_loss: 6.4652e-04
# Epoch 60/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.3015e-04 - val_loss: 7.1023e-04
# Epoch 61/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.3807e-04 - val_loss: 4.9832e-04
# Epoch 62/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.1223e-04 - val_loss: 4.4214e-04
# Epoch 63/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 8.6638e-05 - val_loss: 4.1912e-04
# Epoch 64/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.0037e-04 - val_loss: 4.2762e-04
# Epoch 65/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 1.0295e-04 - val_loss: 4.0854e-04
# Epoch 66/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 9.1810e-05 - val_loss: 3.9693e-04
# Epoch 67/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 9.1344e-05 - val_loss: 3.9027e-04
# Epoch 68/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 8.2534e-05 - val_loss: 4.3060e-04
# Epoch 69/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 1.0115e-04 - val_loss: 3.9175e-04
# Epoch 70/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 7.9350e-05 - val_loss: 3.8695e-04
# Epoch 71/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 8.9843e-05 - val_loss: 3.6932e-04
# Epoch 72/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 8.7178e-05 - val_loss: 4.3595e-04
# Epoch 73/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 8.4903e-05 - val_loss: 4.0482e-04
# Epoch 74/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 8.4613e-05 - val_loss: 3.8611e-04
# Epoch 75/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 8.5863e-05 - val_loss: 3.5165e-04
# Epoch 76/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 8.1547e-05 - val_loss: 3.7596e-04
# Epoch 77/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 8.4419e-05 - val_loss: 3.8370e-04
# Epoch 78/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 8.3781e-05 - val_loss: 6.9165e-04
# Epoch 79/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 1.6184e-04 - val_loss: 3.4836e-04
# Epoch 80/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 7.8619e-05 - val_loss: 4.1518e-04
# Epoch 81/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 8.4129e-05 - val_loss: 4.0193e-04
# Epoch 82/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 9.1416e-05 - val_loss: 3.6973e-04
# Epoch 83/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 9.1655e-05 - val_loss: 3.2930e-04
# Epoch 84/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 7.7778e-05 - val_loss: 3.9754e-04
# Epoch 85/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 1.0340e-04 - val_loss: 3.2990e-04
# Epoch 86/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 8.5801e-05 - val_loss: 3.3596e-04
# Epoch 87/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.2479e-05 - val_loss: 3.2077e-04
# Epoch 88/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.7366e-05 - val_loss: 3.2300e-04
# Epoch 89/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 7.9926e-05 - val_loss: 3.2348e-04
# Epoch 90/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 7.4218e-05 - val_loss: 4.1378e-04
# Epoch 91/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.5077e-05 - val_loss: 4.0755e-04
# Epoch 92/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 8.6589e-05 - val_loss: 3.9719e-04
# Epoch 93/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 8.4364e-05 - val_loss: 3.7589e-04
# Epoch 94/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 7.7879e-05 - val_loss: 3.3009e-04
# Epoch 95/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.2275e-05 - val_loss: 3.4181e-04
# Epoch 96/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 7.6651e-05 - val_loss: 3.1596e-04
# Epoch 97/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 8.1300e-05 - val_loss: 3.1373e-04
# Epoch 98/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.6255e-05 - val_loss: 3.3831e-04
# Epoch 99/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 6.7827e-05 - val_loss: 3.1865e-04
# Epoch 100/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.6659e-05 - val_loss: 3.1624e-04

# %%
train_predict = model_2.predict(X_train)
test_predict = model_2.predict(X_test)

train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

train_rmse = math.sqrt(mean_squared_error(scaler.inverse_transform(y_train.reshape(-1, 1)), train_predict))
test_rmse = math.sqrt(mean_squared_error(scaler.inverse_transform(y_test.reshape(-1, 1)), test_predict))

print(f"Training RMSE: {train_rmse:.4f}")
print(f"Testing RMSE: {test_rmse:.4f}")
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Training RMSE: 5.7538
# Testing RMSE: 11.6932

# %%
train_plot = np.empty_like(data_scaled)
train_plot[:, :] = np.nan
train_plot[time_step:len(train_predict) + time_step, :] = train_predict

test_plot = np.empty_like(data_scaled)
test_plot[:, :] = np.nan
test_plot[len(train_predict) + (time_step * 2) + 1:len(data_scaled) - 1, :] = test_predict

# %%
plt.figure(figsize=(14, 8))
plt.plot(scaler.inverse_transform(data_scaled), label='Original Data')
plt.plot(train_plot, label='Training Predictions')
plt.plot(test_plot, label='Testing Predictions')
plt.title('Tesla Stock Price Prediction Using LSTM for Open feature')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# ### LSTM Model For High feature

# %%
tesla = pd.read_csv("./Data/tesla_data.csv")

High_data = tesla[['High']].values

scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(High_data)

# %%
def create_dataset(dataset, time_step=1):
    High_dataX, High_dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]  
        High_dataX.append(a)
        High_dataY.append(dataset[i + time_step, 0]) 
    return np.array(High_dataX), np.array(High_dataY)

# %%
training_size = int(len(data_scaled) * 0.8)  
test_size = len(data_scaled) - training_size  
train_data, test_data = data_scaled[0:training_size, :], data_scaled[training_size:len(data_scaled), :]

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

model_3 = tf.keras.Sequential([
    tf.keras.layers.LSTM(50, return_sequences=True, input_shape=(100, 1)), 
    tf.keras.layers.LSTM(50, return_sequences=False),  
    tf.keras.layers.Dense(25), 
    tf.keras.layers.Dense(1) 
])
model_3.summary()
# Out:
# C:\Users\Abhi\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                        │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_5 (LSTM)                        │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 25)                  │           1,275 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              26 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 31,901 (124.61 KB)
#  Trainable params: 31,901 (124.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_3.compile(optimizer='adam', loss='mean_squared_error')

model_3.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 0.0160 - val_loss: 0.0012
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 3.5672e-04 - val_loss: 0.0012
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 2.4896e-04 - val_loss: 0.0012
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 1.9829e-04 - val_loss: 0.0012
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 1.9586e-04 - val_loss: 0.0011
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 2.1748e-04 - val_loss: 0.0012
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 2.0544e-04 - val_loss: 0.0011
# Epoch 8/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 2.1742e-04 - val_loss: 0.0010
# Epoch 9/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 2.0597e-04 - val_loss: 0.0011
# Epoch 10/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 1.8538e-04 - val_loss: 0.0010
# Epoch 11/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 1.9231e-04 - val_loss: 0.0010
# Epoch 12/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 1.7430e-04 - val_loss: 9.0916e-04
# Epoch 13/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 1.7618e-04 - val_loss: 9.2809e-04
# Epoch 14/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 1.6720e-04 - val_loss: 8.5825e-04
# Epoch 15/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 1.6707e-04 - val_loss: 0.0011
# Epoch 16/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 1.7597e-04 - val_loss: 8.5647e-04
# Epoch 17/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 1.5199e-04 - val_loss: 8.3525e-04
# Epoch 18/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 1.6590e-04 - val_loss: 7.5750e-04
# Epoch 19/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 1.6174e-04 - val_loss: 7.3658e-04
# Epoch 20/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 1.4906e-04 - val_loss: 9.8069e-04
# Epoch 21/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 1.8017e-04 - val_loss: 7.0439e-04
# Epoch 22/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 1.4735e-04 - val_loss: 7.8704e-04
# Epoch 23/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 1.4164e-04 - val_loss: 7.4281e-04
# Epoch 24/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss:
100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 7.1933e-05 - val_loss: 3.1046e-04
# Epoch 70/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 6.8058e-05 - val_loss: 3.0372e-04
# Epoch 71/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 6.2492e-05 - val_loss: 2.9898e-04
# Epoch 72/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 6.6242e-05 - val_loss: 3.0035e-04
# Epoch 73/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 6.6723e-05 - val_loss: 3.2890e-04
# Epoch 74/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 6.5553e-05 - val_loss: 3.2338e-04
# Epoch 75/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 6.0688e-05 - val_loss: 2.8757e-04
# Epoch 76/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 5.7627e-05 - val_loss: 3.2992e-04
# Epoch 77/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 6.6523e-05 - val_loss: 2.9849e-04
# Epoch 78/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 5.5184e-05 - val_loss: 3.2428e-04
# Epoch 79/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 7.6426e-05 - val_loss: 3.1104e-04
# Epoch 80/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 5.8847e-05 - val_loss: 2.7112e-04
# Epoch 81/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 5.9039e-05 - val_loss: 2.6226e-04
# Epoch 82/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 6.6646e-05 - val_loss: 2.9650e-04
# Epoch 83/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 6.1850e-05 - val_loss: 2.7607e-04
# Epoch 84/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 5.6471e-05 - val_loss: 3.0302e-04
# Epoch 85/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 5.6458e-05 - val_loss: 2.7449e-04
# Epoch 86/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 5.2308e-05 - val_loss: 2.8458e-04
# Epoch 87/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 5.8612e-05 - val_loss: 2.5054e-04
# Epoch 88/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 5.4177e-05 - val_loss: 4.0969e-04
# Epoch 89/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 5.9449e-05 - val_loss: 2.9918e-04
# Epoch 90/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 5.5261e-05 - val_loss: 3.4120e-04
# Epoch 91/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 6.3111e-05 - val_loss: 3.0761e-04
# Epoch 92/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 5.5237e-05 - val_loss: 2.3962e-04
# Epoch 93/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 5.3174e-05 - val_loss: 2.3651e-04
# Epoch 94/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 5.5839e-05 - val_loss: 2.3671e-04
# Epoch 95/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 4.9066e-05 - val_loss: 2.6709e-04
# Epoch 96/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 4.6495e-05 - val_loss: 2.2448e-04
# Epoch 97/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 4.9639e-05 - val_loss: 2.2073e-04
# Epoch 98/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 5.3970e-05 - val_loss: 2.9900e-04
# Epoch 99/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 4.8275e-05 - val_loss: 3.9089e-04
# Epoch 100/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 5.8973e-05 - val_loss: 2.5274e-04

# %%
train_predict = model_3.predict(X_train)
test_predict = model_3.predict(X_test)

train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

train_rmse = math.sqrt(mean_squared_error(scaler.inverse_transform(y_train.reshape(-1, 1)), train_predict))
test_rmse = math.sqrt(mean_squared_error(scaler.inverse_transform(y_test.reshape(-1, 1)), test_predict))

print(f"Training RMSE: {train_rmse:.4f}")
print(f"Testing RMSE: {test_rmse:.4f}")
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Training RMSE: 5.4377
# Testing RMSE: 12.2334

# %%
train_plot = np.empty_like(data_scaled)
train_plot[:, :] = np.nan
train_plot[time_step:len(train_predict) + time_step, :] = train_predict

test_plot = np.empty_like(data_scaled)
test_plot[:, :] = np.nan
test_plot[len(train_predict) + (time_step * 2) + 1:len(data_scaled) - 1, :] = test_predict

# %%
plt.figure(figsize=(14, 8))
plt.plot(scaler.inverse_transform(data_scaled), label='Original Data')
plt.plot(train_plot, label='Training Predictions')
plt.plot(test_plot, label='Testing Predictions')
plt.title('Tesla Stock Price Prediction Using LSTM for High feature')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# ### LSTM model For Low feature

# %%
tesla = pd.read_csv("./Data/tesla_data.csv")

Low_data = tesla[['Low']].values

scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(Low_data)

# %%
def create_dataset(dataset, time_step=1):
    Low_dataX, Low_dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]  
        Low_dataX.append(a)
        Low_dataY.append(dataset[i + time_step, 0]) 
    return np.array(Low_dataX), np.array(Low_dataY)

# %%
training_size = int(len(data_scaled) * 0.8)  
test_size = len(data_scaled) - training_size  
train_data, test_data = data_scaled[0:training_size, :], data_scaled[training_size:len(data_scaled), :]

# %%
time_step = 100

X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

model_4 = tf.keras.Sequential([
    tf.keras.layers.LSTM(50, return_sequences=True, input_shape=(100, 1)), 
    tf.keras.layers.LSTM(50, return_sequences=False),  
    tf.keras.layers.Dense(25), 
    tf.keras.layers.Dense(1) 
])
model_4.summary()
# Out:
# C:\Users\Abhi\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                        │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_7 (LSTM)                        │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 25)                  │           1,275 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 1)                   │              26 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 31,901 (124.61 KB)
#  Trainable params: 31,901 (124.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_4.compile(optimizer='adam', loss='mean_squared_error')

model_4.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 0.0228 - val_loss: 0.0023
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 6.5138e-04 - val_loss: 0.0021
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 4.1602e-04 - val_loss: 0.0021
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 3.8934e-04 - val_loss: 0.0019
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 3.6571e-04 - val_loss: 0.0022
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 3.7268e-04 - val_loss: 0.0021
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 3.5497e-04 - val_loss: 0.0017
# Epoch 8/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 3.5185e-04 - val_loss: 0.0016
# Epoch 9/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 3.0768e-04 - val_loss: 0.0017
# Epoch 10/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 3.2507e-04 - val_loss: 0.0016
# Epoch 11/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 2.9196e-04 - val_loss: 0.0014
# Epoch 12/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 3.0821e-04 - val_loss: 0.0014
# Epoch 13/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 2.6078e-04 - val_loss: 0.0013
# Epoch 14/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 2.5940e-04 - val_loss: 0.0013
# Epoch 15/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 2.4516e-04 - val_loss: 0.0011
# Epoch 16/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 2.4618e-04 - val_loss: 0.0011
# Epoch 17/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 2.3371e-04 - val_loss: 0.0011
# Epoch 18/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 2.2177e-04 - val_loss: 9.8593e-04
# Epoch 19/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 2.1144e-04 - val_loss: 9.3254e-04
# Epoch 20/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 2.3070e-04 - val_loss: 0.0011
# Epoch 21/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 2.2403e-04 - val_loss: 9.0089e-04
# Epoch 22/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 1.8428e-04 - val_loss: 8.6422e-04
# Epoch 23/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 2.1840e-04 - val_loss: 8.4528e-04
# Epoch 24/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 2.0279e-04 - val_loss: 7.7944e-04
# Epoch 25/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 2.1619e-04 - val_loss: 8.1739e-04
# Epoch 26/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 1.6428e-04 - val_loss: 7.4273e-04
# Epoch 27/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 1.6921e-04 - val_loss: 7.2924e-04
# Epoch 28/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 1.6797e-04 - val_loss: 7.7946e-04
# Epoch 29/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss:
100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 8.0112e-05 - val_loss: 3.3634e-04
# Epoch 76/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 7.1550e-05 - val_loss: 3.4819e-04
# Epoch 77/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.7324e-05 - val_loss: 4.2166e-04
# Epoch 78/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 7.8530e-05 - val_loss: 4.0772e-04
# Epoch 79/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 1.0133e-04 - val_loss: 3.1405e-04
# Epoch 80/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 8.6267e-05 - val_loss: 3.0951e-04
# Epoch 81/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.5240e-05 - val_loss: 3.5527e-04
# Epoch 82/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 7.0960e-05 - val_loss: 3.0599e-04
# Epoch 83/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 7.6506e-05 - val_loss: 3.0242e-04
# Epoch 84/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.0475e-05 - val_loss: 3.0146e-04
# Epoch 85/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 7.7771e-05 - val_loss: 3.0165e-04
# Epoch 86/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 8.0990e-05 - val_loss: 3.2370e-04
# Epoch 87/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.3127e-05 - val_loss: 3.0543e-04
# Epoch 88/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 7.6700e-05 - val_loss: 3.3004e-04
# Epoch 89/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 8.0977e-05 - val_loss: 3.3543e-04
# Epoch 90/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 8.6940e-05 - val_loss: 3.1607e-04
# Epoch 91/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 6.9802e-05 - val_loss: 2.8633e-04
# Epoch 92/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 6.5163e-05 - val_loss: 2.9505e-04
# Epoch 93/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 6.7503e-05 - val_loss: 2.9486e-04
# Epoch 94/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 8.5235e-05 - val_loss: 2.9209e-04
# Epoch 95/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 8.2244e-05 - val_loss: 3.0316e-04
# Epoch 96/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.2987e-05 - val_loss: 4.3274e-04
# Epoch 97/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 8.4493e-05 - val_loss: 3.0707e-04
# Epoch 98/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 7.1018e-05 - val_loss: 3.0540e-04
# Epoch 99/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 7.9538e-05 - val_loss: 3.1916e-04
# Epoch 100/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 9.4887e-05 - val_loss: 2.7947e-04

# %%
train_predict = model_4.predict(X_train)
test_predict = model_4.predict(X_test)

train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

train_rmse = math.sqrt(mean_squared_error(scaler.inverse_transform(y_train.reshape(-1, 1)), train_predict))
test_rmse = math.sqrt(mean_squared_error(scaler.inverse_transform(y_test.reshape(-1, 1)), test_predict))

print(f"Training RMSE: {train_rmse:.4f}")
print(f"Testing RMSE: {test_rmse:.4f}")
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Training RMSE: 5.2888
# Testing RMSE: 11.0090

# %%
train_plot = np.empty_like(data_scaled)
train_plot[:, :] = np.nan
train_plot[time_step:len(train_predict) + time_step, :] = train_predict

test_plot = np.empty_like(data_scaled)
test_plot[:, :] = np.nan
test_plot[len(train_predict) + (time_step * 2) + 1:len(data_scaled) - 1, :] = test_predict

# %%
plt.figure(figsize=(14, 8))
plt.plot(scaler.inverse_transform(data_scaled), label='Original Data')
plt.plot(train_plot, label='Training Predictions')
plt.plot(test_plot, label='Testing Predictions')
plt.title('Tesla Stock Price Prediction Using LSTM for Low feature')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# ### LSTM model with ['Open','High','Low','Close'] as features

# %%
tesla = pd.read_csv("./Data/tesla_data.csv")
tesla.head(3) # reading of the data from the start again for LSTM model
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800

# %%
features = tesla[['Open','High','Low','Close']].values

# %%
scaler = MinMaxScaler( feature_range = (0,1))
data_scaled = scaler.fit_transform(features)
data_scaled
# Out:
# array([[0.00434948, 0.01087705, 0.00388739, 0.01058623],
#        [0.01467569, 0.0179205 , 0.01263401, 0.01050772],
#        [0.01347426, 0.01207262, 0.00803292, 0.00806072],
#        ...,
#        [0.93723668, 0.8242258 , 0.91569226, 0.81786181],
#        [0.94876435, 0.82698079, 0.93774107, 0.83063335],
#        [1.        , 1.        , 1.        , 1.        ]])

# %%
def create_dataset(dataset, time_step = 1):
    X,Y = [], []
    for i in range(len(dataset) - time_step-1):
        a = dataset[i:(i + time_step), :]
        X.append(a)
        Y.append(dataset[i + time_step, -1 ])
    return np.array(X), np.array(Y)

# %%
train = int(len(data_scaled) * 0.70)
test = len(data_scaled) - train
train_data , test_data = data_scaled[0: train, :], data_scaled[train:len(data_scaled), :]

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 4)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1],4)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(50, return_sequences=True, input_shape=(100, 4)), 
    tf.keras.layers.LSTM(50, return_sequences=False),  
    tf.keras.layers.Dense(25), 
    tf.keras.layers.Dense(1)  
])
model.summary()
# Out:
# C:\Users\Abhi\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_8 (LSTM)                        │ (None, 100, 50)             │          11,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_9 (LSTM)                        │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 25)                  │           1,275 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 1)                   │              26 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 32,501 (126.96 KB)
#  Trainable params: 32,501 (126.96 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Stacked LSTM Model

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)

train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

train_predict = scaler.inverse_transform(np.concatenate((np.zeros((len(train_predict), 3)), train_predict), axis=1))[:, 3]
test_predict = scaler.inverse_transform(np.concatenate((np.zeros((len(test_predict), 3)), test_predict), axis=1))[:, 3]
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 0.0098 - val_loss: 0.0014
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 3.4655e-04 - val_loss: 0.0015
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 1.7386e-04 - val_loss: 0.0012
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 1.5538e-04 - val_loss: 0.0012
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 1.5340e-04 - val_loss: 0.0012
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 1.5838e-04 - val_loss: 0.0012
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 1.6442e-04 - val_loss: 0.0011
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 1.5248e-04 - val_loss: 0.0011
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 1.5961e-04 - val_loss: 0.0010
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 1.3146e-04 - val_loss: 9.6259e-04
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 1.4470e-04 - val_loss: 0.0011
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 1.4342e-04 - val_loss: 0.0010
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 1.3882e-04 - val_loss: 0.0010
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 1.1962e-04 - val_loss: 0.0012
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 1.3398e-04 - val_loss: 9.7353e-04
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 1.2424e-04 - val_loss: 9.8254e-04
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 1.1198e-04 - val_loss: 0.0011
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 1.1309e-04 - val_loss: 0.0010
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 1.1363e-04 - val_loss: 8.2113e-04
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 1.0967e-04 - val_loss: 0.0017
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 1.2953e-04 - val_loss: 0.0011
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 1.0430e-04 - val_loss: 9.7960e-04
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 9.3928e-05 - val_loss: 9.1454e-04
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 1.0669e-04 - val_loss: 7.1276e-04
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss:
100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 4.0603e-05 - val_loss: 3.6796e-04
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 5.1142e-05 - val_loss: 2.5459e-04
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 4.1168e-05 - val_loss: 2.7557e-04
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 6.1339e-05 - val_loss: 2.2868e-04
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 4.7774e-05 - val_loss: 2.2271e-04
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 4.7974e-05 - val_loss: 2.6475e-04
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 4.8138e-05 - val_loss: 2.3187e-04
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 4.5827e-05 - val_loss: 2.1577e-04
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 4.8935e-05 - val_loss: 2.8039e-04
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 4.1289e-05 - val_loss: 2.3535e-04
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 3.9002e-05 - val_loss: 2.1681e-04
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 4.7285e-05 - val_loss: 3.6610e-04
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 4.9419e-05 - val_loss: 2.6029e-04
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 4.2158e-05 - val_loss: 2.3145e-04
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 4.9337e-05 - val_loss: 2.5332e-04
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 4.0841e-05 - val_loss: 3.2177e-04
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 4.4546e-05 - val_loss: 3.5312e-04
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 4.0138e-05 - val_loss: 2.1208e-04
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 3.9567e-05 - val_loss: 3.7365e-04
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 6.0325e-05 - val_loss: 2.7661e-04
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 4.4182e-05 - val_loss: 2.7099e-04
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 4.0528e-05 - val_loss: 2.3828e-04
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 4.3801e-05 - val_loss: 2.7670e-04
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 4.1100e-05 - val_loss: 2.7517e-04
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 3.6201e-05 - val_loss: 2.3041e-04
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 3.9636e-05 - val_loss: 2.1527e-04
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 5.3699e-05 - val_loss: 3.0278e-04
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 4.3243e-05 - val_loss: 3.0067e-04
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 3.7108e-05 - val_loss: 2.5032e-04
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 4.3520e-05 - val_loss: 2.1641e-04
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
train_rmse = math.sqrt(mean_squared_error(y_train, train_predict))
test_rmse = math.sqrt(mean_squared_error(y_test, test_predict))

print(f"Training RMSE: {train_rmse:.9f}")
print(f"Testing RMSE: {test_rmse:.9f}")
# Out:
# Training RMSE: 168.758237741
# Testing RMSE: 314.112230108

# %%
train_plot = np.empty_like(data_scaled[:,3])
train_plot[:] = np.nan
train_plot[time_step:len(train_predict) + time_step] = train_predict

test_plot = np.empty_like(data_scaled[:,3])
test_plot[:] = np.nan
test_plot[len(train_predict) + (time_step * 2) + 1:len(data_scaled) - 1] = test_predict

plt.figure(figsize=(8, 5))
plt.plot(scaler.inverse_transform(data_scaled), label=['Open','High','Low','Close'])
plt.plot(train_plot, label='Training Predictions')
plt.plot(test_plot, label='Testing Predictions')
plt.title('Tesla Stock Price Prediction Using LSTM')
plt.xlabel('Time(Steps_count)')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# The Graph plotted based on the features open close low and high from the data. The Graph is also included the Training predicted values and testing predicted values as well. With this kind we can able to analyze the model and compared with the data as well.
